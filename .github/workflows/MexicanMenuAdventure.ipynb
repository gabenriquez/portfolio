# %%
## Created by Gabriela Enriquez Manzano, MSBA 2020 SF ##

#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
#*# Try this game, and try visiting MEXICO   #*#
#*# Welcome to 'Mexican Menu Adventure Game'#*#
#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#*#
"""
Mexico offers a diversity of culture, history, art, food, music, travel, 
drinks and expressions that are known around the world. 
If you haven’t visit yet, at least you have 'tasted',
heard or seen a bit of us in movies, menus, music and many restaurants.

We like having fun, making friends and enjoying life, 
try this game today and find out if you have Aztec magic. 

This game simulates the adventure of your experience with a Mexican Menu

"""

#Introduction

print("""
Imagine:
You get to Mexico City, you have a delicious menu, try the 3 stages of meals:
appetizers, specialties and dessert. 

You MUST get to every stage so you get your meal for free. 

But before we start: No, we don’t use Tabasco. 

Do you dare finding out the level of Mexican inside your soul?

=====INSTRUCTIONS:======
1)You will be offered the a special menu of the day, 
..remember this is a virtual world so its FREE.

2)You will be asked a question on each stage, 
you can earn points, and exchange them at the end for a surprise prize
of this virtual Mexican gourmet experience.

3)Our service is personalized, so at the biginning we will ask
your name to provide the best service.
===HAVE FUN=====""")
#^^^Improvements after feedback from users testing: shorter instructions


import time
time.sleep(1)

input("\n<Press Enter to be assigned to a table>")

#Defined variables
human = str
pesos = 0
questions = 3

print("\n<What's your name?>")
human = input()

print(f"\n Welcome {human}!")

#time.sleep(1)

#Defined Menus for appetizer
#while questions > 0:
    
apt_list = ["Nachos with chorizo (meat)","Tostadas sampler (tuna and shrimp)","Nopales (vegan friendly)"]

print("\nTime for APPETIZERS, please select 1, 2 or 3 from this menu:"
      ,"\n1)",apt_list[0],"\n2)", apt_list[1],"\n3)",apt_list[2])

apt_order = input(f"\n<What option would you like for appetizer,{human}?>\n")

#questions = questions-1

#nested conditions to start the experience
if apt_order == "1":
    print("\n---> ----> ---->")
    print("\nMuchos", apt_list[0], "on the way!")
    print("\n---> ----> ---->")

elif apt_order == "2":
    print("\n---> ----> ---->")
    print("\nYou will enjoy your",apt_list[1],"for sure!")
    print("\n---> ----> ---->")

elif apt_order == "3":
    print("\n---> ----> ---->")
    print("Got it,",apt_list[2]," are so tasty and delicious, great choice")
    print("\n---> ----> ---->")

else:
    print("\nAy Diosito, something went wrong, but life goes on")

    
time.sleep(1)

trivia_1 = input(f"""
\nOne first question while you wait for your order: 
\n+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+
\n *Color TV was invented in Mexico*
\n+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+
\n<Type T for TRUE, or F, for FALSE on the next fact>
""")
if trivia_1 == "T" or trivia_1 =="t":
    pesos = int(pesos) +20
    print("""\nWoooho, first $20 for you! 
          \nFYI:That's the price of Corona in Mexico""")
else:
    print("\nTime to learn: YES, Color TV was invented in Mexico in 1942.")
    
print(f"\nEnjoy your apetizer, {human}")

input("<Press enter when you are ready for our specialties>\n")

#^^^Improvements after feedback from users testing: Explain ingredients on the options


spc_list = ["Enchiladas poblanas (chicken)","Chamorro (beef)","Mexican Quinoa Salad (vegan friendly)"]

print("\nTime for the main dish, please select 1, 2 or 3 from this menu:",
      "\n1)", spc_list[0],"\n2)",spc_list[1],"\n3)",spc_list[2])

spc_order = input(f"\nWhat dish would you like to order,{human}? \n")

#nested conditions depending on the human hunger
if spc_order == "1":
    print("\n---> ----> ---->")
    print("Nice, one order of ",spc_list[0],"for you")
    print("\n---> ----> ---->")

elif spc_order == "2":
    print("\n---> ----> ---->")
    print("Okidokie, one delicious",spc_list[1],"on the way!")
    print("\n---> ----> ---->")

elif spc_order == "3":
    print("\n---> ----> ---->")
    print("Very healthy option, we will get you one",spc_list[2])
    print("\n---> ----> ---->")

else:
    print("\nAy Diosito, something went wrong. But we will fix it soon")
    
    
trivia_2 = input(f"""
\nOne more question while we cook your dish, 
\n+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+
\n *Mexicans love celebrating 5 de Mayo*
\n+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+
\n<Type T for TRUE, or F, for FALSE on the next fact>
""")

if trivia_2 == "F"or trivia_2 == "f":
    pesos = int(pesos) +30
    print("\nWoooho, now +$30 for you! That's equivalent to a guacamole order")
else:
    print("""\nTime to learn:NO, we don't make a big deal about it. 
          \nIt is not our Independence Day, it commemorates
          the Mexican Army's victory over the 
          French Empire at the Battle of Puebla""")

print("\nNow you have $:",pesos)

print("\nHere is your main dish, buen provecho!")


#Defined Menus for dessert
input("""~~Did you know..STRESSED is DESSERT spelled backwards?~~
<Press enter whenever you are ready for dessert>\n""")

dsr_list=["Churros rellenos (chocolate flavour)","Arroz con leche(vanilla)","Caramel flan(home recipe)"]

print("\nDESSERT TIME, select your favorite from this menu:",
      "\n1)",dsr_list[0],"\n2)",dsr_list[1],"\n3)",dsr_list[2])
dsr_order=input(f"\nWhat did you decide {human} ?")

#nested conditions depending on the sweet preferences 
if dsr_order =="1":
    print("\n---> ----> ---->")
    print("Sweet way to end this time")
    print("\n---> ----> ---->")

elif dsr_order=="2":
    print("\n---> ----> ---->")
    print(dsr_list[1], "is made with lots of love, just like granma did")
    print("\n---> ----> ---->")

elif dsr_order=="3":
    print("\n---> ----> ---->")
    print("That",dsr_list[2],"is going to delight you!")
    print("\n---> ----> ---->")

else:
    print("""
    \nWe were so close to make it, but the universe fail on us. 
    \nSorry!""")
      
trivia_3 = input(f"""\n{human} ,you can now earn $50 pesos with this LAST question while we get your dessert, 
    \n+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+
    \n*Mexico is the origin of chocolate*
    \n+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+
    \n <Type T for TRUE, or F, for FALSE on this SWEET fact>""")

if trivia_3 =="T" or trivia_3 == "t":
    pesos = int(pesos) +50
    print("""\nYES! Sí Señor!! Now +$50 for you! That's the price of a Tequila shot in Mexico,
    \n..if you are over 21""")
    
else:
    print("""\nFriend, today you learned that is TRUE.
          \nThe Aztecs even had their own chocolate Goddess, Ixcacao.""")
    
print("\nYour final balance is $:",pesos, "pesos")
time.sleep(1)
#pesos did not update on this round
#now is working because the condition was not writen correctly

print("\nHere is your dessert")
time.sleep(1)



#Defining the prize function, since its free, its random even though they try to make money for answering correctly
import random

def regalito():
    import random

    num = random.randint(1,3)
    input("""
    \nWe know you tried hard answering the trivia, so prize will be random
    \n<Press enter and you will get a RANDOM PRIZE>""")
    
    print("This is what the universe sent you:")
    if num==1:
        print("""\nYou get a TEXMEX gift:
              \n 1 Corona, cheers!""",'and you get your $:',pesos)
    elif num==2:
        print("""\nYou get a WANNABE MEX gift:
              \n 1 Guacamole order""",'and you get your $:',pesos)
    elif num==3:
        print("""\nYou get a MEXICANISIMO:
              \n 1 Tequila shot""",'and you get your $:',pesos,'hopefully you are 21')

regalito()

print("\nWe are closer to the end, thanks for your time!")
time.sleep(1)

print("\n *Music plays*")

##One loop to play some music
canta = ['Ay', 'ay','ay', 'ay','canta', 'y no llores']
for frase in canta: 
    time.sleep(.5)
    print (frase)
time.sleep(1)
print("\n ***Music stops**")
time.sleep(1)

print("\nHasta la vista, ",human,"!","\n+ + + THIS IS THE END. + + +")

##This game was tasted with humans: Americans, Italians, Czechs, Indians and Colombians
##Users learned and got hungry at the same time, if it happens to you, just visit MEXICO
##Warning: do not try too many Mexican food outside Mexico, it might break your heart
##Thanks for reading this.. You rock, amigos!
# Out:
# Imagine:
# You get to Mexico City, you have a delicious menu, try the 3 stages of meals:
# appetizers, specialties and dessert.
#
# You MUST get to every stage so you get your meal for free.
#
# But before we start: No, we don’t use Tabasco.
#
# Do you dare finding out the level of Mexican inside your soul?
#
# =====INSTRUCTIONS:======
# 1)You will be offered the a special menu of the day,
# ..remember this is a virtual world so its FREE.
#
# 2)You will be asked a question on each stage,
# you can earn points, and exchange them at the end for a surprise prize
# of this virtual Mexican gourmet experience.
#
# 3)Our service is personalized, so at the biginning we will ask
# your name to provide the best service.
# ===HAVE FUN=====
#
# <Press Enter to be assigned to a table>
#
# <What's your name?>
# Franklin
#
#  Welcome Franklin!
#
# Time for APPETIZERS, please select 1, 2 or 3 from this menu:
# 1) Nachos with chorizo (meat)
# 2) Tostadas sampler (tuna and shrimp)
# ...
